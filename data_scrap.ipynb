# %%
# from lxml import etree,html
import json
# from itertools import repeat, chain
# from concurrent.futures import ThreadPoolExecutor

import requests
import pandas as pd
import numpy as np
import urllib3
from bs4 import BeautifulSoup
import os

# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

# %%
# https://www.innovatoretfs.com/define/etfs/
# https://www.innovatoretfs.com/define/etfs/#allproducts
# "https://www.basketball-reference.com/teams/PHI/2022/lineups/"

# %%
pd.read_html("https://www.innovatoretfs.com/define/etfs/")
# Out:
# [                                                   0  \
#  0  Filter by Reference Asset: SPY / S&P 500QQQ / ...
#
#                                                     1  \
#  0  Filter by Type:  Buffer (9%)Power Buffer (15%)...
#
#                                                   2  \
#  0  Filter by Rebalance Frequency:  AnnualQuarterly
#
#                                                     3
#  0  Filter by Series: JanuaryMaySeptemberFebruaryJ...  ,
#                                                     0  \
#  0  Filter by Reference Asset: SPY / S&P 500QQQ / ...
#
#                                                     1  \
#  0  Filter by Type:  Buffer (9%)Power Buffer (15%)...
#
#                                                   2  \
#  0  Filter by Rebalance Frequency:  AnnualQuarterly
#
#                                                     3
#  0  Filter by Series: JanuaryMaySeptemberFebruaryJ...  ,
#                                                   0
# ...

# %%
url = "https://www.innovatoretfs.com/define/etfs/"
headers = {'User-Agent': 'Codeup Data Science'} # Some websites don't accept the pyhon-requests default user-agent
response = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
data_test = soup.find_all('table')[4]

# %%
for child in soup.find_all('table').children:
    for td in child:
        print(td.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
#       1 for child in soup.find('table').children:
#       2     for td in child:
# ----> 3         print(td.text)
#
# AttributeError: 'str' object has no attribute 'text'

# %%
# I was able to narrow down to a specific table data row. But nothing more than that.

soup.find_all('tr')[0].text
# Out:
# '\n\nFilter by Reference Asset: \nSPY / S&P 500QQQ / Nasdaq-100IWM / Russell 2000EFA - iShares MSCI EAFE ETFEEM - iShares MSCI EM ETFTLT - 20+ Year Treasuries\n\nReset All\n\n\nFilter by Type:\nBuffer (9%)Power Buffer (15%)Ultra Buffer (30%)Wealth ShieldStacker2X Accelerated3X AcceleratedFloor (5%)\n\n\nFilter by Rebalance Frequency:\nAnnualQuarterly\n\n\nFilter by Series: \nJanuaryMaySeptemberFebruaryJuneOctoberMarchJulyNovemberAprilAugustDecember\n\n'
